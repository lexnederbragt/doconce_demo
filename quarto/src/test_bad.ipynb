# %% [markdown]
# #
#
# ![Figure 1: An Elephant](attachment:elephant.png)
#
# This is illustrated well by [Figure 1](#fig-elephant).

# %% [markdown]
# <img src="elephant.png" width="600"> Figure 1: An elephant.
